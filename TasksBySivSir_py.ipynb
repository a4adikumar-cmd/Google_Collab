# %% [markdown]
# <a href="https://colab.research.google.com/github/a4adikumar-cmd/Google_Collab/blob/main/TasksBySivSir_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
name = input("Enter name: ")
print(name.upper())
# Out:
# Enter name: aditya
# ADITYA

# %%
#2
city = input("Enter name: ")
print(city)
print(city.lower())
print(city.upper())
print(city.title())
# Out:
# Enter name: Rourkela
# Rourkela
# rourkela
# ROURKELA
# Rourkela

# %%
#3
s = input("Input a String: ")
print(len(s))
# Out:
# Input a String: fgyt
# 4

# %%
#4
s = input("Input a String: ")
print(s[0])
print(s[-1])
# Out:
# Input a String: kamal
# k
# l

# %%
#5
s = input("Input a String: ")
c = input("Character to count: ")
print(s.count(c))
# Out:
# Input a String: Adiitya
# Character to count: i
# 2

# %%
#6
s = "Python stands for Artificial Intelligent."
print(s.replace("Python", "AI"))
# Out:
# AI stands for Artificial Intelligent.

# %%
#7
mail = input("enter mail")
if(mail.endswith("@gmail.com")):
  print("Gmail address")
else:
  print("Not a Gmail address")
# Out:
# enter mailadi566@gmail.com
# Gmail address

# %%
#8
s = input("Enter a string")
if(s.isdigit()):
  print("Contains only digits.")
else:
  print("Doesnot contains only digits")
# Out:
# Enter a string4588
# Contains only digits.

# %%
#9
s = input("Enter a string: ")
if(s.isalpha()):
  print("Contains only alphabates.")
else:
  print("Doesnot contains only alphabates")
# Out:
# Enter a string: 456
# Doesnot contains only alphabates

# %%
#10
s = "Apple, Mango, Banana, Orange"
print(s.split(","))
# Out:
# ['Apple', ' Mango', ' Banana', ' Orange']

# %%
#11
age = int(input("Enter age: "))
if (age > 18):
  print("Eligible for votes.")
else:
  print("Not eligible for votes.")
# Out:
# Enter age: 2
# Not eligible for votes.

# %%
#12
n = int(input("Enter a number: "))
if (n>0):
  print(n," is positive.")
elif (n<0):
  print(n," is negative.")
else:
  print(n," is 0.")
# Out:
# Enter a number: 4
# 4  is positive.

# %%
#13
n1 = int(input("Enter num1: "))
n2 = int(input("Enter num2: "))
print("Greater number is ",max(n1,n2))
# Out:
# Enter num1: 4
# Enter num2: 5
# Greater number is  5

# %%
#14
Marks = int(input("Enter Marks: "))
if(90 <= Marks <= 100):
  print("Grade: A")
elif(75 <= Marks <= 89):
  print("Grade: B")
elif(50 <= Marks <= 74):
  print("Grade: C")
elif(Marks < 50):
  print("Fail")
else:
  print("Total marks are 100.")
# Out:
# Enter Marks: 65
# Grade: C

# %%
#15
n = int(input("Enter number: "))
if(n%2 == 0):
  print("Even")
else:
  print("Odd")
# Out:
# Enter number: 3
# Odd

# %%
#16
pwd = input("Enter a pwd: ")
if(len(pwd) >= 8):
  print("Strong Password.")
else:
  print("Weak Password.")
# Out:
# Enter a pwd: ncxfgxbf
# Strong Password.

# %%
#17
y = int(input("Enter year: "))
if((y%100 != 0 and y%4 == 0) or y%400 == 0):
  print(y," is a leap year")
else:
  print(y," is not a leap year")
# Out:
# Enter year: 2024
# 2024  is a leap year

# %%
#18
n1 = int(input("Enter num1: "))
n2 = int(input("Enter num2: "))
n3 = int(input("Enter num3: "))
print(max(n1,n2,n3))
# Out:
# Enter num1: 4
# Enter num2: 5
# Enter num3: 6
# 6

# %%
#19
Username = input("Enter Username: ")
if(Username == "admin"):
  Password = int(input("Enter password: "))
  if(Password == 1234):
    print("Login successful")
  else:
    print("Invalid credentials")
else:
  print("Invalid credentials")
# Out:
# Enter Username: admin
# Enter password: 123
# Invalid credentials

# %%
#20
n1 = int(input())
n2 = input()
n3 = int(input())
match n2:
  case "+":
    print(n1 + n3)
  case "-":
    print(n1 - n3)
  case "*":
    print(n1 * n2)
  case "/":
    print(n1 / n2)
# Out:
# 4
# +
# 5
# 9

# %% [markdown]
# <a href="https://colab.research.google.com/github/a4adikumar-cmd/Google_Collab/blob/main/TaskBySivSir_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
l = ["Adi", "Ram", "Sachi", "Krushna", "Kamal"]
print(l)
# Out:
# ['Adi', 'Ram', 'Sachi', 'Krushna', 'Kamal']

# %%
#2
l = ["Adi", "Ram", "Sachi", "Krushna", "Kamal"]
print("First element: ", l[0])
print("Last element: ", l[-1])
# Out:
# First element:  Adi
# Last element:  Kamal

# %%
#3
l = ["apple", "banana", "guava"]
l.append("mango")
print("Updated list: ", l)
# Out:
# Updated list:  ['apple', 'banana', 'guava', 'mango']

# %%
#4
l = ["DLD", "jAVA", "DBMS", "DSA"]
l.insert(3, "AI")
print(l)
# Out:
# ['DLD', 'jAVA', 'DBMS', 'AI', 'DSA']

# %%
#5
l = ["Adi", "Ram", "Sachi", "Krushna", "Kamal"]
l.pop(3)
print(l)
# Out:
# ['Adi', 'Ram', 'Sachi', 'Kamal']

# %%
#6
l = [10, 20, 30, 40, 50]
print(len(l))
print(max(l))
print(min(l))
print(sum(l))
# Out:
# 5
# 50
# 10
# 150

# %%
#7
l = input("Enter 5 elements: ").split()
print(l)
# Out:
# Enter 5 elements: 4 5 6 8 9
# ['4', '5', '6', '8', '9']

# %%
#8
cities = ["Chennai", "Bangaluru", "Mumbai", "Goa", "Noida"]
if "Delhi" in cities:
  print("Delhi is in the list.")
else:
  print("Delhi is not in the list")
# Out:
# Delhi is not in the list

# %%
#9
t = ["Green", "Black", "White", "Red", "Brown"]
print(*t, sep = "\n")
# Out:
# Green
# Black
# White
# Red
# Brown

# %%
#10
t = (10, 20, 30, 40, 50)
print("first element: ", t[0])
print("Last element: ", t[-1])
# Out:
# first element:  10
# Last element:  50

# %%
#11
t = ["Adi", "Ram", "Sachi", "Krushna", "Kamal", "Ram"]
count_of_Ram = t.count("Ram")
print(count_of_Ram)
# Out:
# 2

# %%
#12
t = (10, 20, 30, 40, 50)
print("Maximum of the list: ", max(t))
print("Minimum of the list: ", min(t))
print("Length of the list: ", len(t))
# Out:
# Maximum of the list:  50
# Minimum of the list:  10
# Length of the list:  5

# %%
#13
t = (10, 20, 30, 40, 50)
t[1] = 100
print(t)
#TypeError: 'tuple' object does not support item assignment


t.append(100)
print(t)
#AttributeError: 'tuple' object has no attribute 'append'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2153/581559096.py in <cell line: 0>()
#       7 """
#       8
# ----> 9 t.append(100)
#      10 print(t)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
#14
t = (1, 2, 3, 4, 5)
l = list(l)
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %%
#15
s = {10, 20, 30, 40, 50}
print(s)
# Out:
# {50, 20, 40, 10, 30}

# %%
#16
s = {10, 20, 30}
s.add(40)
print(s)
# Out:
# {40, 10, 20, 30}

# %%
#17
s = {10, 20, 30, 40}
s.remove(20)
print(s)
# Out:
# {40, 10, 30}

# %%
#18
s = {10, 20, 30, 30, 40, 40}
print(s)

#Set doesnot allow duplicate values
# Out:
# {40, 10, 20, 30}

# %%
#19
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}
print("Union: ", A | B)
print("Intersection: ", A & B)
# Out:
# Union:  {1, 2, 3, 4, 5, 6}
# Intersection:  {3, 4}

# %%
#20
s = {1, 2, 3, 4}
i = input("Enter a number to check: ")

if i in s:
  print(i," is in the set")
else:
  print(i," is not in the set")
# Out:
# Enter a number to check: 5
# 5  is not in the set

# %%
#21
d = {"Name": "Adi", "Age": 21, "City": "Chennai"}
print(d.values())
# Out:
# dict_values(['Adi', 21, 'Chennai'])

# %%
#22
d = {"Name": "Adi", "Age": 21, "City": "Chennai"}
d.update({"course":"Python"})
print(d)
# Out:
# {'Name': 'Adi', 'Age': 21, 'City': 'Chennai', 'course': 'Python'}

# %%
#23
employee = {"Name": "Adi", "Age": 21, "City": "Chennai"}
print(employee.keys())
print(employee.values())
# Out:
# dict_keys(['Name', 'Age', 'City'])
# dict_values(['Adi', 21, 'Chennai'])

# %%
#24
d = {"Name": "Adi", "Age": 21, "City": "Chennai"}
d["City"] = "Brahmapur"
print(d)
# Out:
# {'Name': 'Adi', 'Age': 21, 'City': 'Brahmapur'}

# %%
#25
d = {
"name":"Test",
"age":24,
"city":"Chennai"
}

del d["city"]
print(d)
# Out:
# {'name': 'Test', 'age': 24}

# %%
#26
d = {"Ram" : 90, "Adi" : 67, "Krushna" : 90, "Kamal" : 89, "Sachi" : 85}
print(d.keys())
# Out:
# dict_keys(['Ram', 'Adi', 'Krushna', 'Kamal', 'Sachi'])

# %%
#27
d = {"Amul lassi" : 10,
     "Amul Moti" : 32,
     "Surf Excel" : 10,
     "Cinthol" : 10}

i = input("Enter product name: ")

if i in d:
  print(d[i])
else :
  print("Product not found.")
# Out:
# Enter product name: Amul Moti
# 32

# %%
#28
d = {"Amul lassi" : 10,
     "Amul Moti" : 32,
     "Surf Excel" : 10,
     "Cinthol" : 10}

i = input("Enter product name: ")

if i in d:
  print("Product exists.")
else :
  print("Product doesnot exist.")
# Out:
# Enter product name: nvdgdshg
# Product doesnot exist.

# %%
#29
l = ["Adi", "Ram", "Sachi", "Krushna", "Kamal"]
t = tuple(l)
print(t, type(t))
# Out:
# ('Adi', 'Ram', 'Sachi', 'Krushna', 'Kamal') <class 'tuple'>

# %%
#30
d = {"Ram" : 90, "Adi" : 67, "Krushna" : 90, "Kamal" : 89, "Sachi" : 85, "Satya" : 67}
for i in d.keys():
  if d[i] > 80 :
    print(i)
# Out:
# Ram
# Krushna
# Kamal
# Sachi
